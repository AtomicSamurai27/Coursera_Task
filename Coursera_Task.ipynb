# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # <H1>My Jupyter Notebook on IBM Watson Studio<H1>

# %% [markdown]
# __Mario Hernández__
#
# Mechanical Engineer

# %% [markdown]
# _I find data science interesting because of its way of obtaining information from data to later explain a phenomenon or find the solution to a problem_
#
# _I am interested in data science because I see a future in which the data scientist will be a profession with high demand_

# %% [markdown]
# <H3> The following code calculate the square root of a number.<H3>

# %%
print ("math.sqrt(1000) :" , math.sqrt(1000))
print ("math.sqrt(100) : ", math.sqrt(100))
print ("math.sqrt(10) : ", math.sqrt(10))
# Out:
# math.sqrt(1000) : 31.622776601683793
# math.sqrt(100) :  10.0
# math.sqrt(10) :  3.1622776601683795

# %% [markdown]
# <a href="https://www.linkedin.com/company/ibm/?trk=public_profile_experience-item_profile-section-card_subtitle-click&originalSubdomain=ve">IBM LinkedIn Profile</a>
#
# | <h5>Language<h5> | <h5>Database<h5> |
# | ------ | ------ |
# | C | IBM DB2 |
# | C++ | MySQL |
# | Python | PostgreSQL |
# | Go | MongoDB |
# | Java | CouchDB |
#
# Social Networks:
# - Instagram
# - Twitter
# - Facebook
# - LinkedIn
#
# ![The Eye of God.jpg](attachment:338a5180-0fbd-4232-8769-3a2f579ec791.jpg)
